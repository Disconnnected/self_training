# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get("https://vnexpress.net/bong-da")

# %%
result = r.text
result
# Out:
# '<!DOCTYPE html>\n<html lang="vi" xmlns="http://www.w3.org/1999/xhtml">\n<head>\n<title>Tin Bóng đá, báo bóng đá 24h, lịch thi đấu, bxh bóng đá mới nhất</title> <meta name="description" content="Tin tức Bóng Đá mới nhất 24h qua, tường thuật trực tiếp bóng đá, xem bóng đá trực tuyến, bảng xếp hạng, lịch thi đấu, kết quả bóng đá hôm nay - VnExpress."/>\n<meta name="keywords" content="bóng đá, bong da, trực tiếp bóng đá, bongda24h, bongdaso, kết quả bóng đá, tin bong da"/>\n<meta name="news_keywords" content="bóng đá, bong da, trực tiếp bóng đá, bongda24h, bongdaso, kết quả bóng đá, tin bong da"/>\n<meta charset="utf-8">\n<meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=5, user-scalable=1" name="viewport"/>\n<meta http-equiv="X-UA-Compatible" content="IE=100"/>\n<meta property="fb:app_id" content="1547540628876392"/>\n<meta http-equiv="REFRESH" content="1800"/>\n<meta name="apple-mobile-web-app-capable" content="yes"/>\n<meta name="apple-mobile-web-app-title" content="Vnexpress.net"/>\n<meta name="tt_article_id" content="1002567"/>\n<meta name="tt_category_id" content="1002567"/>\n<meta name="tt_site_id" content="1002565"/>\n<meta name="tt_site_id_new" content="1002565"/>\n<meta name="tt_list_folder" content="1000000,1002565,1002567"/>\n<meta name="tt_list_folder_name" content="VnExpress,Thể thao,Bóng đá"/>\n<meta name="tt_page_type" content="folder"/>\n<meta name="tt_page_type_new" content="2"/>\n<!-- add meta for pvtt3334 -->\n<!-- end meta for pvtt -->\n<!-- META FOR FACEBOOK -->\n<meta property="og:site_name" content="vnexpress.net"/>\n<meta property="og:rich_attachment" content="true"/>\n<meta property="og:type" content="website"/>\n<meta property="og:url" itemprop="url" content="https://vnexpress.net/bong-da"/>\n<meta property="og:image" itemprop="thumbnailUrl" content="https://s1.vnecdn.net/vnexpress/restruct/i/v771/logo_default.jpg"/>\n<meta property="og:image:width" content="800"/>\n<meta property="og:image:height" content="354"/>\n<meta content="Tin Bóng đá, báo bóng đá 24h, lịch thi đấu, bxh bóng đá mới nhất" itemprop="headline" property="og:title"/>\n<meta content="Tin tức Bóng Đá mới nhất 24h qua, tường thuật trực tiếp bóng đá, xem bóng đá trực tuyến, bảng xếp hạng, lịch thi đấu, kết quả bóng đá hôm nay - VnExpress." itemprop="description" property="og:description"/>\n<!-- END META FOR FACEBOOK -->\n<meta content="news" itemprop="genre" name="medium"/>\n<meta content="vi-VN" itemprop="inLanguage"/>\n<meta content="" itemprop="articleSection"/>\n<meta content="Tin nhanh VnExpress" itemprop="sourceOrganization" name="source"/>\n<meta name="copyright" content="VnExpress"/>\n<meta name="author" content="VnExpress"/>\n<meta name="robots" content="index,follow"/>\n<meta name="geo.placename" content="Ha Noi, Viet Nam"/>\n<meta name="geo.region" content="VN-HN"/>\n<meta name="geo.position" content="21.030624;105.782431"/>\n<meta name="ICBM" content="21.030624, 105.782431"/>\n<meta name="revisit-after" content="days"/>\n<!-- Twitter Card -->\n<meta name="twitter:card" value="summary"/>\n<meta name="twitter:url" content="https://vnexpress.net/bong-da"/>\n<meta name="twitter:title" content="Tin Bóng đá, báo bóng đá 24h, lịch thi đấu, bxh bóng đá mới nhất"/>\n<meta name="twitter:description" content="Tin tức Bóng Đá mới nhất 24h qua, tường thuật trực tiếp bóng đá, xem bóng đá trực tuyến, bảng xếp hạng, lịch thi đấu, kết quả bóng đá hôm nay - VnExpress."/>\n<meta name="twitter:image" content="https://s1.vnecdn.net/vnexpress/restruct/i/v771/logo_default.jpg"/>\n<meta name="twitter:site" content="@VnEnews"/>\n<meta name="twitter:creator" content="@VnEnews"/>\n<!-- End Twitter Card -->\n<link rel="canonical" href="https://vnexpress.net/bong-da"/>\n<link rel="alternate" href="https://vnexpress.net/bong-da" hreflang="vi-vn"/>\n<link rel="dns-prefetch" href="https://s1.vnecdn.net"/>\n<link rel="dns-prefetch" href="https://s.eclick.vn"/>\n<link rel="dns-prefetch" href="https://gw.vnexpress.net"/>\n<link ...

# %%
soup = BeautifulSoup(r.content, 'html.parser')

# %%
# Getting the title tag
print(soup.title)
 
# Getting the name of the tag
print(soup.title.name)
 
# Getting the name of parent tag
print(soup.title.parent.name)
# Out:
# <title>Tin Bóng đá, báo bóng đá 24h, lịch thi đấu, bxh bóng đá mới nhất</title>
# title
# head

# %%
# Finding Elements by class
s = soup.find('div', class_='container')
s
content = s.find_all('span')
content
# Out:
# [<span class="hamburger"></span>,
#  <span class="time-now">Thứ sáu, 12/5/2023</span>,
#  <span class="txt-area">
#  <span class="dot-blue dot-region-news hidden"></span>
#  <svg fill="none" height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg">
#  <path d="M10 7C10 8.65685 8.65685 10 7 10C5.34315 10 4 8.65685 4 7C4 5.34315 5.34315 4 7 4C8.65685 4 10 5.34315 10 7ZM9 7C9 5.89543 8.10457 5 7 5C5.89543 5 5 5.89543 5 7C5 8.10457 5.89543 9 7 9C8.10457 9 9 8.10457 9 7ZM11.9497 11.955C14.6834 9.2201 14.6834 4.78601 11.9497 2.05115C9.21608 -0.683716 4.78392 -0.683716 2.05025 2.05115C-0.683418 4.78601 -0.683418 9.2201 2.05025 11.955L3.57128 13.4538L5.61408 15.4389L5.74691 15.5567C6.52168 16.1847 7.65623 16.1455 8.38611 15.4391L10.8223 13.0691L11.9497 11.955ZM2.75499 2.75619C5.09944 0.410715 8.90055 0.410715 11.245 2.75619C13.5294 5.04153 13.5879 8.71039 11.4207 11.0667L11.245 11.2499L9.92371 12.5539L7.69315 14.7225L7.60016 14.8021C7.24594 15.0699 6.7543 15.0698 6.40012 14.802L6.30713 14.7224L3.3263 11.817L2.75499 11.2499L2.57927 11.0667C0.412077 8.71039 0.47065 5.04153 2.75499 2.75619Z" fill="#9F9F9F"></path>
#  </svg>
#  Tin theo khu vực
#  </span>,
#  <span class="dot-blue dot-region-news hidden"></span>]

# %%
# Finding by id
s = soup.find('div', id= 'main')
 
# Getting the leftbar
leftbar = s.find('ul', class_='leftBarList')
 
# All the li under the above ul
content = leftbar.find_all('li')

# %%
f = open("draft.txt", "w", encoding="utf-8")
f.write(str(soup))
f.close
# Out:
# <function TextIOWrapper.close()>

# %%
import numpy as np
import pandas as pd

# %%
arr = np.arange(10,25).reshape(3,5)
arr
df = pd.DataFrame(arr)
df
# Out:
#     0   1   2   3   4
# 0  10  11  12  13  14
# 1  15  16  17  18  19
# 2  20  21  22  23  24

# %%
# pd.DataFrame()
# df = pd.read_csv("../simple_student.csv")
student = pd.read_csv("../simple_student.csv")
student
# Out:
#             ID                     Name Sex  Mark            Note
# 0  Nestech_001         Nguyen Phu Trong   M    10      Lop Truong
# 1  Nestech_002            Vo Van Thuong   M     9  Pho Lop Truong
# 2  Nestech_003  Nguyen Hoang Kieu Trinh   F     4             NaN
# 3  Nestech_004            Viktor Nguyen   M     7             NaN
# 4  Nestech_005             Clint Nguyen   M     7             NaN
# 5  Nestech_006          Nguyen Van Toan   M     9             NaN
# 6  Nestech_007          Kha Kim Bao Han   F    10              Ex
# 7  Nestech_008         Pham Le Tram Anh   F     5              Ex
# 8  Nestech_009       Ba Hoang Kim Thinh   F     3              Ex
# 9  Nestech_010           Giap Phi Hoang   M     6      Y Thuc Kem

# %%
df.to_csv("../new_student_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      10 non-null     object
#  1   Name    10 non-null     object
#  2   Sex     10 non-null     object
#  3   Mark    10 non-null     int64
#  4   Note    6 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 532.0+ bytes

# %%
# df[["Name","Sex", "Mark"]]
student[["Name", "Mark", "Sex"]]
# Out:
#                       Name  Mark Sex
# 0         Nguyen Phu Trong    10   M
# 1            Vo Van Thuong     9   M
# 2  Nguyen Hoang Kieu Trinh     4   F
# 3            Viktor Nguyen     7   M
# 4             Clint Nguyen     7   M
# 5          Nguyen Van Toan     9   M
# 6          Kha Kim Bao Han    10   F
# 7         Pham Le Tram Anh     5   F
# 8       Ba Hoang Kim Thinh     3   F
# 9           Giap Phi Hoang     6   M

# %%
student.head(3)
# Out:
#             ID                     Name Sex  Mark            Note
# 0  Nestech_001         Nguyen Phu Trong   M    10      Lop Truong
# 1  Nestech_002            Vo Van Thuong   M     9  Pho Lop Truong
# 2  Nestech_003  Nguyen Hoang Kieu Trinh   F     4             NaN

# %%
student.tail(5)
# Out:
#             ID                Name Sex  Mark        Note
# 5  Nestech_006     Nguyen Van Toan   M     9         NaN
# 6  Nestech_007     Kha Kim Bao Han   F    10          Ex
# 7  Nestech_008    Pham Le Tram Anh   F     5          Ex
# 8  Nestech_009  Ba Hoang Kim Thinh   F     3          Ex
# 9  Nestech_010      Giap Phi Hoang   M     6  Y Thuc Kem

# %%
student[3:8]
# Out:
#             ID              Name Sex  Mark Note
# 3  Nestech_004     Viktor Nguyen   M     7  NaN
# 4  Nestech_005      Clint Nguyen   M     7  NaN
# 5  Nestech_006   Nguyen Van Toan   M     9  NaN
# 6  Nestech_007   Kha Kim Bao Han   F    10   Ex
# 7  Nestech_008  Pham Le Tram Anh   F     5   Ex

# %%
student.loc[6:]
# Out:
#             ID                Name Sex  Mark        Note
# 6  Nestech_007     Kha Kim Bao Han   F    10          Ex
# 7  Nestech_008    Pham Le Tram Anh   F     5          Ex
# 8  Nestech_009  Ba Hoang Kim Thinh   F     3          Ex
# 9  Nestech_010      Giap Phi Hoang   M     6  Y Thuc Kem

# %%
# df[df["Sex"] == "M"]
student[student["Mark"] == 4]
# Out:
#             ID                     Name Sex  Mark Note
# 2  Nestech_003  Nguyen Hoang Kieu Trinh   F     4  NaN

# %%
student[student.Mark > 7]
# Out:
#             ID                     Name Sex  Mark        Note
# 2  Nestech_003  Nguyen Hoang Kieu Trinh   F     4         NaN
# 7  Nestech_008         Pham Le Tram Anh   F     5          Ex
# 8  Nestech_009       Ba Hoang Kim Thinh   F     3          Ex
# 9  Nestech_010           Giap Phi Hoang   M     6  Y Thuc Kem

# %%
high_score = df[(df.Mark > 7) & (df.Sex == "M")]
high_score.to_csv("../high_score.csv")
# new_df = df[(df.Mark > 7) & (df.Sex == "M")]

# %%
# df["DoubleMark"] = df["Mark"] * 2
student["Triple Mark"] = student["Mark"] * 3
student
# Out:
#             ID                     Name Sex  Mark            Note  Triple Mark
# 0  Nestech_001         Nguyen Phu Trong   M    10      Lop Truong           30
# 1  Nestech_002            Vo Van Thuong   M     9  Pho Lop Truong           27
# 2  Nestech_003  Nguyen Hoang Kieu Trinh   F     4             NaN           12
# 3  Nestech_004            Viktor Nguyen   M     7             NaN           21
# 4  Nestech_005             Clint Nguyen   M     7             NaN           21
# 5  Nestech_006          Nguyen Van Toan   M     9             NaN           27
# 6  Nestech_007          Kha Kim Bao Han   F    10              Ex           30
# 7  Nestech_008         Pham Le Tram Anh   F     5              Ex           15
# 8  Nestech_009       Ba Hoang Kim Thinh   F     3              Ex            9
# 9  Nestech_010           Giap Phi Hoang   M     6      Y Thuc Kem           18

# %%
student["Pass/Fail"] = np.where(df["Note"] == "Y Thuc Kem","Fail","Pass")
# student["Pass/Fail"] = np.where(df["Mark"]>5,"Pass","Fail")
# x = np.where("condition", if True, if False)
student
# Out:
#             ID                     Name Sex  Mark            Note  \
# 0  Nestech_001         Nguyen Phu Trong   M    10      Lop Truong
# 1  Nestech_002            Vo Van Thuong   M     9  Pho Lop Truong
# 2  Nestech_003  Nguyen Hoang Kieu Trinh   F     4             NaN
# 3  Nestech_004            Viktor Nguyen   M     7             NaN
# 4  Nestech_005             Clint Nguyen   M     7             NaN
# 5  Nestech_006          Nguyen Van Toan   M     9             NaN
# 6  Nestech_007          Kha Kim Bao Han   F    10              Ex
# 7  Nestech_008         Pham Le Tram Anh   F     5              Ex
# 8  Nestech_009       Ba Hoang Kim Thinh   F     3              Ex
# 9  Nestech_010           Giap Phi Hoang   M     6      Y Thuc Kem
#
#    Triple Mark Pass/Fail
# 0           30      Pass
# 1           27      Pass
# 2           12      Pass
# 3           21      Pass
# 4           21      Pass
# 5           27      Pass
# 6           30      Pass
# 7           15      Pass
# ...

# %%
# sửa cột
# student.loc[0:2,['Num','NAME']] = [100,'Python']
student.loc[0:2, ["Nguyen Phu Trong", 10]] == ["Quang", 10]
student
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 3
#       1 # sửa cột
#       2 # student.loc[0:2,['Num','NAME']] = [100,'Python']
# ----> 3 student.loc[0:2, ["Nguyen Phu Trong", 10]] == ["Quang", 10]
#       4 student
#
# File c:\Users\Viktor\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File c:\Users\Viktor\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1256, in _LocIndexer._getitem_tuple(self, tup)
#    1253 if self._multi_take_opportunity(tup):
# ...

# %%
df.drop(columns=["DoubleMark"])
df.drop(columns=["DoubleMark"], inplace=True)
df = df.drop(columns=["DoubleMark"])

# %%
df.drop(index=[1,2])
# index='cow', columns='small'
